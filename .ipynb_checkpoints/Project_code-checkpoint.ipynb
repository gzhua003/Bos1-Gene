# %%
import itertools
import sys
import re

# %%
def isheader(line):
    return line[0] == '>'

# %%
def aspairs(f):
    seq_id = ''
    sequence = ''
    for header,group in itertools.groupby(f, isheader):
        if header:
            line = next(group)
            seq_id = line[1:].split()[0]
        else:
            sequence = ''.join(line.strip() for line in group)
            yield seq_id, sequence

if len(sys.argv) <= 1:
    print("expecting on cmdline argument: fasta_parser.py FILE.fasta")
    exit()

# %%
#BF1.fas = sys.argv[1]
filename="BF1.fas"
with open(filename,"r") as f:
    pairs = aspairs(f)
    seqs  = dict(pairs)
#print(seqs)
# assume that these are aligned so all the same length
# so use the length of 1st one to determine len
first = ""

for name in seqs:
    first = name
    break
print(first)
#total_length = len(seqs[first])
print ('total len is ',total_length)
for name in seqs:
    print(name, 'is',len(seqs[name]),'long')
#    print(seqs[name])

# %%
for i in range(total_length):
    col = set()
    column_text = ""
    for name in seqs:
        base = seqs[name][i]
        if base == "N" or base == "-":
            continue # skip the 'N' bases or '-'
        # could change this to calculate frequence
        # by using a dictionary instead of a set here
        col.add(base)
        column_text += base
    print(f'colummn # {i} is {col}')
    print(column_text)

# %%
filename = "BF1.fas"
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Assuming sequences are aligned and have the same length
first_seq = next(iter(seqs.values()))

for i in range(len(first_seq)):
    bases_at_position = set(seq[i] for seq in seqs.values() if seq[i] not in {"N", "-"})
    
    if len(bases_at_position) > 1:
        print(f"Position {i+1} has differences:")
        for name, base in seqs.items():
            print(f"{name}: {base[i]}", end=" ")
        print("\n")

# %%
filename = "BF1.fas"
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Assuming sequences are aligned and have the same length
first_seq = next(iter(seqs.values()))
total_positions = len(first_seq)

# Dictionary to store the frequency of differences at each position
difference_freq = {}

for i in range(total_positions):
    bases_at_position = [seq[i] for seq in seqs.values() if seq[i] not in {"N", "-"}]

    if len(set(bases_at_position)) > 1:
        differences = " ".join(bases_at_position)
        if differences not in difference_freq:
            difference_freq[differences] = 1
        else:
            difference_freq[differences] += 1

# Display the frequency of differences at each position
print("Frequency of differences at each position:")
for differences, freq in difference_freq.items():
    print(f"Position {differences}: {freq} times")

# Display the top 10 positions with the highest frequency of differences
top_10 = sorted(difference_freq.items(), key=lambda x: x[1], reverse=True)[:10]
print("\nTop 10 positions with the highest frequency of differences:")
for differences, freq in top_10:
    print(f"Position {differences}: {freq} times")

# %%
filename = "BF1.fas"
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Assuming sequences are aligned and have the same length
first_seq = next(iter(seqs.values()))
total_positions = len(first_seq)

# Dictionary to store the frequency of differences at each position
difference_freq = {}

for i in range(total_positions):
    bases_at_position = [seq[i] for seq in seqs.values() if seq[i] not in {"N", "-"}]

    if len(set(bases_at_position)) > 1:
        differences = " ".join(bases_at_position)
        if differences not in difference_freq:
            difference_freq[differences] = 1
        else:
            difference_freq[differences] += 1

# Display the top 10 positions with the highest frequency of differences
top_10 = sorted(difference_freq.items(), key=lambda x: x[1], reverse=True)[:10]
print("\nTop 10 positions with the highest frequency of differences:")
for differences, freq in top_10:
    print(f"Position {differences}: {freq} times")

# %%
filename = "BF1.fas"
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Assuming sequences are aligned and have the same length
first_seq = next(iter(seqs.values()))
total_positions = len(first_seq)

# Dictionary to store the total number of differences for each strain
strain_total_difference = {}

for name, sequence in seqs.items():
    differences_count = sum(1 for i in range(total_positions) if sequence[i] not in {"N", "-"})
    strain_total_difference[name] = differences_count

# Rank strains based on the total number of differences
ranked_strains = sorted(strain_total_difference.items(), key=lambda x: x[1], reverse=True)
print("\nRanking of strains based on the total number of differences across all positions:")
for rank, (name, differences_count) in enumerate(ranked_strains, 1):
    print(f"{rank}. {name}: {differences_count} differences")

# %%
# Count and print the number of strains
num_strains = len(seqs)
print(f'Total number of strains: {num_strains}')

# %%
def calculate_sequence_percentage_difference(seq1, seq2):
    """
    Calculate the total sequence percentage difference between two DNA sequences.

    Parameters:
    - seq1: First DNA sequence (string)
    - seq2: Second DNA sequence (string)

    Returns:
    - percentage_difference: Total percentage difference between the sequences (float)
    """
    if len(seq1) != len(seq2):
        raise ValueError("Sequences must have the same length for comparison.")

    differences = sum(1 for base1, base2 in zip(seq1, seq2) if base1 != base2 and base1 not in {"N", "-"} and base2 not in {"N", "-"})
    total_positions = len(seq1)

    percentage_difference = (differences / total_positions) * 100.0
    return percentage_difference


filename = "BF1.fas"

with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Assuming sequences are aligned and have the same length
first_seq = next(iter(seqs.values()))
total_positions = len(first_seq)

# Dictionary to store the total percentage difference for each strain
strain_total_percentage_difference = {}

for name, sequence in seqs.items():
    percentage_difference = calculate_sequence_percentage_difference(first_seq, sequence)
    strain_total_percentage_difference[name] = percentage_difference

# Rank strains based on the total percentage difference
ranked_strains = sorted(strain_total_percentage_difference.items(), key=lambda x: x[1], reverse=True)
print("\nRanking of strains based on the total percentage difference across all positions:")
for rank, (name, percentage_difference) in enumerate(ranked_strains, 1):
    print(f"{rank}. {name}: {percentage_difference:.2f}% difference")

# %%
filename = "BF1.fas"

# Open the file and read DNA sequences
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Print available sequence names
print("Available sequence names:", list(seqs.keys()))

# Specify the correct reference sequence name based on the output
reference_sequence_name = "B35"  # Replace with the correct name

# Check if the specified reference sequence name exists
if reference_sequence_name not in seqs:
    raise KeyError(f"The specified reference sequence '{reference_sequence_name}' is not found in the FASTA file.")

# Use the specified reference sequence
reference_sequence = seqs[reference_sequence_name]

# Dictionary to store the total percentage difference for each strain
strain_total_percentage_difference = {}

# Calculate the percentage difference for each strain relative to the reference
for name, sequence in seqs.items():
    percentage_difference = calculate_sequence_percentage_difference(reference_sequence, sequence)
    strain_total_percentage_difference[name] = percentage_difference

# Rank strains based on the total percentage difference
ranked_strains = sorted(strain_total_percentage_difference.items(), key=lambda x: x[1], reverse=True)

# Print the ranking
print("\nRanking of strains based on the total percentage difference from the reference:")
for rank, (name, percentage_difference) in enumerate(ranked_strains, 1):
    print(f"{rank}. {name}: {percentage_difference:.2f}% difference from {reference_sequence_name}")

# %%
filename = "BF1.fas"

# Open the file and read DNA sequences
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Print available sequence names
print("Available sequence names:", list(seqs.keys()))

# Specify the reference sequence name
reference_sequence_name = "F09_B35_BF"  # Replace with the correct name

# Check if the specified reference sequence name exists
if reference_sequence_name not in seqs:
    raise KeyError(f"The specified reference sequence '{reference_sequence_name}' is not found in the FASTA file.")

# Use the specified reference sequence
reference_sequence = seqs[reference_sequence_name]

# Dictionary to store the total percentage difference for each strain
strain_total_percentage_difference = {}

# Calculate the percentage difference for each strain relative to the reference
for name, sequence in seqs.items():
    percentage_difference = calculate_sequence_percentage_difference(reference_sequence, sequence)
    strain_total_percentage_difference[name] = percentage_difference

# Rank strains based on the total percentage difference
ranked_strains = sorted(strain_total_percentage_difference.items(), key=lambda x: x[1], reverse=True)

# Print the ranking
print("\nRanking of strains based on the total percentage difference from the reference:")
for rank, (name, percentage_difference) in enumerate(ranked_strains, 1):
    print(f"{rank}. {name}: {percentage_difference:.2f}% difference from {reference_sequence_name}")

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

filename = "BF1.fas"

# Open the file and read DNA sequences
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Specify the strain to exclude
strain_to_exclude = 'JX192620.1'

# Create a DataFrame with DNA sequences, excluding the specified strain
df = pd.DataFrame(list(seqs.items()), columns=['Strain', 'Sequence'])
df.set_index('Strain', inplace=True)
df.drop(index=strain_to_exclude, inplace=True)

# Convert DNA sequences to numerical data (e.g., 0 for 'A', 1 for 'C', 2 for 'G', 3 for 'T')
# Replace this part with your actual method for converting sequences to numerical data
numerical_data = df['Sequence'].apply(lambda seq: [ord(base) for base in seq])

# Convert numerical_data to a 2D array
X = np.array(list(numerical_data))

# Standardize the data
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_standardized)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=X_pca, columns=['Principal Component 1', 'Principal Component 2'])
pca_df.index = df.index

# Combine the PCA results with the original data
biplot_df = pd.concat([pca_df, df], axis=1)

# Plot the biplot
plt.figure(figsize=(12, 8))
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.5)

# Plot feature vectors as arrows
feature_vectors = pca.components_.T
for i, (x, y) in enumerate(zip(feature_vectors[:, 0], feature_vectors[:, 1])):
    plt.arrow(0, 0, x, y, color='r', alpha=0.75)
    plt.text(x, y, df.columns[i], color='g')

# Label the axes
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Biplot for 32 Strains (excluding JX192620.1)')
plt.grid(True)
plt.show()

# Plot feature vectors as arrows
feature_vectors = pca.components_.T
for i, (x, y) in enumerate(zip(feature_vectors[:, 0], feature_vectors[:, 1])):
    plt.arrow(0, 0, x, y, color='r', alpha=0.75)
    plt.text(x, y, df.columns[0] if len(df.columns) == 1 else df.columns[i], color='g')

# Label the axes
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Biplot for 32 Strains (excluding JX192620.1)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[172], line 52
#      50 for i, (x, y) in enumerate(zip(feature_vectors[:, 0], feature_vectors[:, 1])):
#      51     plt.arrow(0, 0, x, y, color='r', alpha=0.75)
# ---> 52     plt.text(x, y, df.columns[i], color='g')
#      54 # Label the axes
#      55 plt.xlabel('Principal Component 1')
#
# File /opt/linux/rocky/8.x/x86_64/pkgs/jupyterhub/4.0.2/env/lib/python3.11/site-packages/pandas/core/indexes/base.py:5365, in Index.__getitem__(self, key)
#    5362 if is_integer(key) or is_float(key):
#    5363     # GH#44051 exclude bool, which would return a 2d ndarray
#    5364     key = com.cast_scalar_indexer(key)
# -> 5365     return getitem(key)
#    5367 if isinstance(key, slice):
#    5368     # This case is separated from the conditional above to avoid
#    5369     # pessimization com.is_bool_indexer and ndim checks.
# ...

# %%
filename = "BF1.fas"

# Open the file and read DNA sequences
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Define the group of interest with updated names
group_of_interest = [
    "E05_B2_BF1", "E06_B10_BF", "F06_B11_BF", "D07_B17_BF", "D08_B25_BF",
    "E08_B26_BF", "F08_B27_BF", "B09_B31_BF", "D09_B33_BF", "F09_B35_BF"
]

# Define the sequence to exclude
sequence_to_exclude = "JX192620.1"

# Separate sequences into two groups: group of interest and the rest (excluding JX192620.1)
group_of_interest_sequences = {name: seqs[name] for name in group_of_interest}
other_sequences = {name: seq for name, seq in seqs.items() if name not in group_of_interest and name != sequence_to_exclude}

# Calculate the reference sequence for each group (use the average sequence)
reference_sequence_group_of_interest = calculate_average_sequence(list(group_of_interest_sequences.values()))
reference_sequence_other = calculate_average_sequence(list(other_sequences.values()))

# Dictionary to store the total percentage difference for each strain in each group
percentage_difference_group_of_interest = {}
percentage_difference_other = {}

# Calculate the percentage difference for each strain in each group relative to the group's reference
for name, sequence in group_of_interest_sequences.items():
    percentage_difference = calculate_sequence_percentage_difference(reference_sequence_group_of_interest, sequence)
    percentage_difference_group_of_interest[name] = percentage_difference

for name, sequence in other_sequences.items():
    percentage_difference = calculate_sequence_percentage_difference(reference_sequence_other, sequence)
    percentage_difference_other[name] = percentage_difference

# Calculate the average percentage difference for each group
average_percentage_difference_group_of_interest = sum(percentage_difference_group_of_interest.values()) / len(group_of_interest)
average_percentage_difference_other = sum(percentage_difference_other.values()) / len(other_sequences)

# Print the results
print("\nAverage percentage difference for the group of interest:", average_percentage_difference_group_of_interest)
print("Average percentage difference for the rest of the population (excluding JX192620.1):", average_percentage_difference_other)

# Compare the averages
if average_percentage_difference_group_of_interest < average_percentage_difference_other:
    print("\nThe group of interest is more similar to each other compared to the rest of the population (excluding JX192620.1).")
else:
    print("\nThe group of interest is less similar to each other compared to the rest of the population (excluding JX192620.1).")
# Out:
# Average percentage difference for the group of interest: 0.21587440034888788
# Average percentage difference for the rest of the population (excluding JX192620.1): 0.18435554850731473
#
# The group of interest is less similar to each other compared to the rest of the population (excluding JX192620.1).

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

filename = "BF1.fas"

# Open the file and read DNA sequences
with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)

# Specify the strain to exclude
strain_to_exclude = 'JX192620.1'

# Create a DataFrame with DNA sequences, excluding the specified strain
df = pd.DataFrame(list(seqs.items()), columns=['Strain', 'Sequence'])
df.set_index('Strain', inplace=True)
df.drop(index=strain_to_exclude, inplace=True)

# Convert DNA sequences to numerical data (e.g., 0 for 'A', 1 for 'C', 2 for 'G', 3 for 'T')
# Replace this part with your actual method for converting sequences to numerical data
numerical_data = df['Sequence'].apply(lambda seq: [ord(base) for base in seq])

# Convert numerical_data to a 2D array
X = np.array(list(numerical_data))

# Standardize the data
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_standardized)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=X_pca, columns=['Principal Component 1', 'Principal Component 2'])
pca_df.index = df.index

# Plot the PCA results
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c='blue', edgecolors='k')
plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

filename = "BF1.fas"


with open(filename, "r") as f:
    pairs = aspairs(f)
    seqs = dict(pairs)


strain_to_exclude = 'JX192620.1'


df = pd.DataFrame(list(seqs.items()), columns=['Strain', 'Sequence'])
df.set_index('Strain', inplace=True)
df.drop(index=strain_to_exclude, inplace=True)


numerical_data = df['Sequence'].apply(lambda seq: [ord(base) for base in seq])


X = np.array(list(numerical_data))


scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_standardized)


pca_df = pd.DataFrame(data=X_pca, columns=['Principal Component 1', 'Principal Component 2'])
pca_df.index = df.index


group_of_interest = ['E05_B2_BF1', 'E06_B10_BF', 'F06_B11_BF', 'D07_B17_BF', 'D08_B25_BF', 'E08_B26_BF', 'F08_B27_BF', 'B09_B31_BF', 'D09_B33_BF', 'F09_B35_BF']
pca_df['Group'] = np.where(pca_df.index.isin(group_of_interest), 'Group of Interest', 'Other Strains')


plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'].map({'Group of Interest': 'red', 'Other Strains': 'blue'}), edgecolors='k')
plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(handles=scatter.legend_elements()[0], labels=['Group of Interest', 'Other Strains'])
plt.grid(True)
plt.show()
# Out:
# /opt/linux/rocky/8.x/x86_64/pkgs/jupyterhub/4.0.2/env/lib/python3.11/site-packages/matplotlib/collections.py:1109: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# ... (Your existing code)

# Create a column for grouping: one group for the strains of interest, and one for the rest
group_of_interest = ['E05_B2_BF1', 'E06_B10_BF', 'F06_B11_BF', 'D07_B17_BF', 'D08_B25_BF', 'E08_B26_BF', 'F08_B27_BF', 'B09_B31_BF', 'D09_B33_BF', 'F09_B35_BF']
pca_df['Group'] = np.where(pca_df.index.isin(group_of_interest), 'Group of Interest', 'Other Strains')

# Plot the PCA results with different colors for each group
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'].map({'Group of Interest': 'red', 'Other Strains': 'blue'}), edgecolors='k', label='Strain Grouping')

# Add a legend
plt.legend()

plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Save the plot to a JPEG file
plt.savefig("pca_plot.jpg", format="jpeg", dpi=300)

# Show the plot (optional)
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# ... (Your existing code)

# Create a column for grouping: one group for the strains of interest, and one for the rest
group_of_interest = ['E05_B2_BF1', 'E06_B10_BF', 'F06_B11_BF', 'D07_B17_BF', 'D08_B25_BF', 'E08_B26_BF', 'F08_B27_BF', 'B09_B31_BF', 'D09_B33_BF', 'F09_B35_BF']
pca_df['Group'] = np.where(pca_df.index.isin(group_of_interest), 'Group of Interest', 'Other Strains')

# Plot the PCA results with different colors for each group
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'].map({'Group of Interest': 'red', 'Other Strains': 'blue'}), edgecolors='k', label='Strain Grouping')

# Add a legend
plt.legend()

plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Save the plot to a JPEG file
plt.savefig("pca_plot.jpg", format="jpeg", dpi=300)

# Show the plot (optional)
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# ... (Your existing code)

# Create a column for grouping: one group for the strains of interest, and one for the rest
group_of_interest = ['E05_B2_BF1', 'E06_B10_BF', 'F06_B11_BF', 'D07_B17_BF', 'D08_B25_BF', 'E08_B26_BF', 'F08_B27_BF', 'B09_B31_BF', 'D09_B33_BF', 'F09_B35_BF']
pca_df['Group'] = np.where(pca_df.index.isin(group_of_interest), 'Group of Interest', 'Other Strains')

# Plot the PCA results with different colors for each group
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'].map({'Group of Interest': 'red', 'Other Strains': 'blue'}), edgecolors='k', label='Strain Grouping')

# Add a legend
plt.legend()

plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Save the plot to a JPEG file
plt.savefig("pca_plot.jpg", format="jpeg", dpi=300)

# Show the plot (optional)
plt.show()

# %%
import os
print(os.getcwd())

# %%
filenames = ["/path/to/BF1.fas", "/path/to/BF2.fas", "/path/to/BF3.fas", "/path/to/BF4.fas", "/path/to/BF5.fas"]

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# ... (Your existing code)

# Create a column for grouping: one group for the strains of interest, and one for the rest
group_of_interest = ['E05_B2_BF1', 'E06_B10_BF', 'F06_B11_BF', 'D07_B17_BF', 'D08_B25_BF', 'E08_B26_BF', 'F08_B27_BF', 'B09_B31_BF', 'D09_B33_BF', 'F09_B35_BF']
pca_df['Group'] = np.where(pca_df.index.isin(group_of_interest), 'Group of Interest', 'Other Strains')

# Plot the PCA results with different colors for each group
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'].map({'Group of Interest': 'red', 'Other Strains': 'blue'}), edgecolors='k', label='Strain Grouping')

# Add a legend
plt.legend()

plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Save the plot to a file
plt.savefig("pca_plot.png", format="png", dpi=300)

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# ... (Your existing code)

# Create a column for grouping: one group for the strains of interest, and one for the rest
group_of_interest = ['E05_B2_BF1', 'E06_B10_BF', 'F06_B11_BF', 'D07_B17_BF', 'D08_B25_BF', 'E08_B26_BF', 'F08_B27_BF', 'B09_B31_BF', 'D09_B33_BF', 'F09_B35_BF']
pca_df['Group'] = np.where(pca_df.index.isin(group_of_interest), 'Group of Interest', 'Other Strains')

# Plot the PCA results with different colors for each group
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'].map({'Group of Interest': 'red', 'Other Strains': 'blue'}), edgecolors='k', label='Strain Grouping')

# Add a legend
plt.legend()

plt.title('PCA for All Strains (excluding JX192620.1)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Save the plot to a JPEG file
plt.savefig("pca_plot.jpg", format="jpeg", dpi=300)

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np
import matplotlib.pyplot as plt

# ... (Your existing code)

# Combine sequences from the group of interest and the rest of the population
all_sequences = {**group_of_interest_sequences, **other_sequences}

# Convert DNA sequences to numerical data (e.g., 0 for 'A', 1 for 'C', 2 for 'G', 3 for 'T')
# Replace this part with your actual method for converting sequences to numerical data
numerical_data = [list(map(ord, seq)) for seq in all_sequences.values()]

# Convert numerical_data to a 2D array
X = np.array(numerical_data)

# Standardize the data
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_standardized)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=X_pca, columns=['Principal Component 1', 'Principal Component 2'])
pca_df.index = all_sequences.keys()

# Convert categorical variable to numerical values
le = LabelEncoder()
pca_df['Group'] = le.fit_transform(pca_df.index.map(lambda x: 'Group of Interest' if x in group_of_interest else 'Other Strains'))

# Plot the PCA results with different colors for the group of interest and the rest of the population
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pca_df['Group'], cmap='viridis', edgecolors='k')
plt.title('PCA for Sequences: Group of Interest vs. Other Strains')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(handles=scatter.legend_elements()[0], labels=['Group of Interest', 'Other Strains'])
plt.grid(True)

# Save the plot to a JPEG file
plt.savefig("pca_plot_sequences.jpg", format="jpeg", dpi=300)

# Show the plot (optional)
plt.show()
